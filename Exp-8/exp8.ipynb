# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np

# %%
cfg_file = '/content/yolov3.cfg' 
weight_file = '/content/yolov3.weights' 
namesfile = '/content/coco.names'
net = cv2.dnn.readNet(weight_file, cfg_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 weight_file = '/content/yolov3.weights'
#       3 namesfile = '/content/coco.names'
# ----> 4 net = cv2.dnn.readNet(weight_file, cfg_file)
#
# NameError: name 'cv2' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 net = cv2.dnn.readNet(weight_file, cfg_file)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\darknet\darknet_importer.cpp:210: error: (-212:Parsing error) Failed to open NetParameter file: /content/yolov3.cfg in function 'cv::dnn::dnn4_v20250619::readNetFromDarknet'
